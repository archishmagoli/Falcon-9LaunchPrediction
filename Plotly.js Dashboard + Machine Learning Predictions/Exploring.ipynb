# %%
import pandas as pd
spacex_df = pd.read_csv("spacex_launch_dash.csv")

# %%
filtered_df = spacex_df[spacex_df['Launch Site'] == 'CCAFS LC-40']
filtered_df.head(25)
# Out:
#     Unnamed: 0  Flight Number  Launch Site  class  Payload Mass (kg)  \
# 0            0              1  CCAFS LC-40      0                0.0
# 1            1              2  CCAFS LC-40      0                0.0
# 2            2              3  CCAFS LC-40      0              525.0
# 3            3              4  CCAFS LC-40      0              500.0
# 4            4              5  CCAFS LC-40      0              677.0
# 5            5              7  CCAFS LC-40      0             3170.0
# 6            6              8  CCAFS LC-40      0             3325.0
# 7            7              9  CCAFS LC-40      0             2296.0
# 8            8             10  CCAFS LC-40      0             1316.0
# 9            9             11  CCAFS LC-40      0             4535.0
# 10          10             12  CCAFS LC-40      0             4428.0
# 11          11             13  CCAFS LC-40      0             2216.0
# 12          12             14  CCAFS LC-40      0             2395.0
# 13          13             15  CCAFS LC-40      0              570.0
# 14          14             16  CCAFS LC-40      0             4159.0
# 15          15             17  CCAFS LC-40      0             1898.0
# 16          16             18  CCAFS LC-40      0             4707.0
# 17          17             19  CCAFS LC-40      1             1952.0
# 18          18             20  CCAFS LC-40      1             2034.0
# 19          19             22  CCAFS LC-40      0             5271.0
# 20          20             23  CCAFS LC-40      1             3136.0
# 21          21             24  CCAFS LC-40      1             4696.0
# 22          22             25  CCAFS LC-40      1             3100.0
# 23          23             26  CCAFS LC-40      0             3600.0
# 24          24             27  CCAFS LC-40      1             2257.0
#
#    Booster Version Booster Version Category
# 0   F9 v1.0  B0003                     v1.0
# 1   F9 v1.0  B0004                     v1.0
# 2   F9 v1.0  B0005                     v1.0
# 3   F9 v1.0  B0006                     v1.0
# 4   F9 v1.0  B0007                     v1.0
# 5          F9 v1.1                     v1.1
# 6          F9 v1.1                     v1.1
# 7          F9 v1.1                     v1.1
# 8          F9 v1.1                     v1.1
# 9          F9 v1.1                     v1.1
# 10   F9 v1.1 B1011                     v1.1
# 11   F9 v1.1 B1010                     v1.1
# 12   F9 v1.1 B1012                     v1.1
# 13   F9 v1.1 B1013                     v1.1
# 14   F9 v1.1 B1014                     v1.1
# 15   F9 v1.1 B1015                     v1.1
# 16   F9 v1.1 B1016                     v1.1
# 17   F9 v1.1 B1018                     v1.1
# 18     F9 FT B1019                       FT
# 19     F9 FT B1020                       FT
# 20   F9 FT B1021.1                       FT
# 21     F9 FT B1022                       FT
# 22   F9 FT B1023.1                       FT
# 23     F9 FT B1024                       FT
# 24   F9 FT B1025.1                       FT
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: C:\Users\archi\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting plotly.express
#   Downloading plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\archi\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from plotly.express) (2.0.2)
# Collecting plotly>=4.1.0 (from plotly.express)
#   Using cached plotly-5.16.1-py2.py3-none-any.whl (15.6 MB)
# Collecting statsmodels>=0.9.0 (from plotly.express)
#   Downloading statsmodels-0.14.0-cp310-cp310-win_amd64.whl (9.2 MB)
#                                               0.0/9.2 MB ? eta -:--:--
#                                               0.2/9.2 MB 4.6 MB/s eta 0:00:02
#      --                                       0.6/9.2 MB 7.7 MB/s eta 0:00:02
#      ----                                     1.1/9.2 MB 8.7 MB/s eta 0:00:01
#      -------                                  1.6/9.2 MB 9.4 MB/s eta 0:00:01
#      ---------                                2.1/9.2 MB 9.7 MB/s eta 0:00:01
#      ------------                             2.8/9.2 MB 10.6 MB/s eta 0:00:01
#      --------------                           3.3/9.2 MB 10.6 MB/s eta 0:00:01
#      ----------------                         3.7/9.2 MB 10.4 MB/s eta 0:00:01
#      ------------------                       4.4/9.2 MB 10.7 MB/s eta 0:00:01
#      ---------------------                    5.0/9.2 MB 11.0 MB/s eta 0:00:01
#      ------------------------                 5.5/9.2 MB 11.1 MB/s eta 0:00:01
#      ---------------------------              6.2/9.2 MB 11.7 MB/s eta 0:00:01
#      ------------------------------           6.9/9.2 MB 11.7 MB/s eta 0:00:01
#      ---------------------------------        7.6/9.2 MB 11.9 MB/s eta 0:00:01
#      -----------------------------------      8.2/9.2 MB 12.0 MB/s eta 0:00:01
#      --------------------------------------   8.8/9.2 MB 12.3 MB/s eta 0:00:01
#      ---------------------------------------  9.2/9.2 MB 12.3 MB/s eta 0:00:01
#      ---------------------------------------- 9.2/9.2 MB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=0.18 in c:\users\archi\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from plotly.express) (1.11.1)
# Collecting patsy>=0.5 (from plotly.express)
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#                                               0.0/233.8 kB ? eta -:--:--
#      ------------------------------------- 233.8/233.8 kB 14.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.11 in c:\users\archi\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from plotly.express) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\archi\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=0.20.0->plotly.express) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\archi\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=0.20.0->plotly.express) (2020.5)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\archi\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=0.20.0->plotly.express) (2023.3)
# Requirement already satisfied: six in c:\users\archi\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from patsy>=0.5->plotly.express) (1.16.0)
# Collecting tenacity>=6.2.0 (from plotly>=4.1.0->plotly.express)
#   Using cached tenacity-8.2.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: packaging in c:\users\archi\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from plotly>=4.1.0->plotly.express) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\archi\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from packaging->plotly>=4.1.0->plotly.express) (3.0.9)
# Installing collected packages: tenacity, patsy, plotly, statsmodels, plotly.express
# Successfully installed patsy-0.5.3 plotly-5.16.1 plotly.express-0.4.1 statsmodels-0.14.0 tenacity-8.2.3

# %%
# %pip install plotly.express
import plotly.express as px
fig = px.pie(spacex_df[spacex_df['Launch Site'] == entered_site], values='class', title='Success Rate of Launches for site ' + entered_site)
fig.update_layout()
return fig
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 get_ipython().run_line_magic('pip', 'install plotly.express')
#       2 import plotly.express as px
# ----> 3 fig = px.pie(spacex_df[spacex_df['Launch Site'] == entered_site], values='class', title='Success Rate of Launches for site ' + entered_site)
#       4 fig.update_layout()
#       5 return fig
#
# NameError: name 'entered_site' is not defined
